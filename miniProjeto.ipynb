# %%
import pandas as pd

df_songs = pd.read_csv("songs.csv")
df_artists = pd.read_csv("artists.csv")

# %%
#Diagnosticos iniciais de songs
df_songs.info()
df_songs.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550622 entries, 0 to 550621
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   id                      550622 non-null  object
#  1   name                    550619 non-null  object
#  2   album_name              550602 non-null  object
#  3   artists                 550622 non-null  object
#  4   danceability            550622 non-null  float64
#  5   energy                  550622 non-null  float64
#  6   key                     550622 non-null  int64
#  7   loudness                550622 non-null  float64
#  8   mode                    550622 non-null  int64
#  9   speechiness             550622 non-null  float64
#  10  acousticness            550622 non-null  float64
#  11  instrumentalness        550622 non-null  float64
#  12  liveness                550622 non-null  float64
#  13  valence                 550622 non-null  float64
#  14  tempo                   550622 non-null  float64
#  15  duration_ms             550622 non-null  int64
#  16  lyrics                  550622 non-null  object
#  17  year                    550622 non-null  int64
#  18  genre                   550622 non-null  object
#  19  popularity              550622 non-null  int64
#  20  total_artist_followers  550622 non-null  int64
#  21  avg_artist_popularity   550622 non-null  float64
#  22  artist_ids              550622 non-null  object
#  23  niche_genres            550622 non-null  object
# dtypes: float64(10), int64(6), object(8)
# memory usage: 100.8+ MB
# id                         0
# name                       3
# album_name                20
# artists                    0
# danceability               0
# energy                     0
# key                        0
# loudness                   0
# mode                       0
# speechiness                0
# acousticness               0
# instrumentalness           0
# liveness                   0
# valence                    0
# tempo                      0
# duration_ms                0
# lyrics                     0
# year                       0
# genre                      0
# popularity                 0
# total_artist_followers     0
# avg_artist_popularity      0
# artist_ids                 0
# niche_genres               0
# dtype: int64

# %%
#Diagnosticos iniciais de artists
df_artists.info()
df_artists.shape
df_artists.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71440 entries, 0 to 71439
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          71440 non-null  object
#  1   name        71438 non-null  object
#  2   followers   71440 non-null  int64
#  3   popularity  71440 non-null  int64
#  4   genres      71440 non-null  object
#  5   main_genre  71440 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 3.3+ MB
# id            0
# name          2
# followers     0
# popularity    0
# genres        0
# main_genre    0
# dtype: int64

# %% [markdown]
# Após carregar e diagnosticar os dados, foi possivel ver que os tipos de dados estão corretos, porem ha alguns valores nulos que irei tratar

# %%
#tratamento songs
import ast

df_songs["album_name"] = df_songs["album_name"].fillna("Unknown")
df_songs["name"] = df_songs["name"].fillna("Unknown")
df_songs["niche_genres"] = df_songs["niche_genres"].str.replace("[]","No niche genres")

# %%
#tratamento artists
df_artists["name"] = df_artists["name"].fillna("Unknown")
df_artists[df_artists["id"] == "2ZO5sFPyILDQkFdS4HJPFS"]
# Out:
#                            id     name  followers  popularity  \
# 65272  2ZO5sFPyILDQkFdS4HJPFS  Unknown      45544          32
#
#                 genres main_genre
# 65272  ['black metal']       Rock

# %%
#Função usada para passar artistas e id dos artistas para lista, para explodir e usar merge futuramente
 
import ast
import pandas as pd

def parse_artists(valor):
    if pd.isna(valor):
        return []

    valor = valor.strip()

    if valor.lower() == "none" or valor == "":
        return []

    # string que representa lista
    if valor.startswith("[") and valor.endswith("]"):
        try:
            return ast.literal_eval(valor)
        except:
            return []

    # string simples → vira lista com 1 artista
    return [valor]

df_songs["artists"] = df_songs["artists"].apply(parse_artists)
df_songs["artists"].apply(type).value_counts()
df_songs["artist_ids"] = df_songs["artist_ids"].apply(parse_artists)
df_songs["artist_ids"].apply(type).value_counts()
df_songs
# Out:
#                             id                     name  \
# 0       0Prct5TDjAnEgIqbxcldY9                        !
# 1       2ASl4wirkeYm3OWZxXKYuq                       !!
# 2       5tA3ImW310llKo8EMBj2Ga      !!Noble Stabbings!!
# 3       0fROT4kK5oTm8xO8PX6EJF           !I'll Be Back!
# 4       1xBFhv5faebv3mmwxx7DnS                   !Lost!
# ...                        ...                      ...
# 550617  7ItLwpnDJNmnmjlx4hOC96  A Chance I'd Never Have
# 550618  773j5fNWIjO0EWqAiX8Quo  It's Painless to Let Go
# 550619  0fMJpTECbr7MwQYJjopAWf               Once Again
# 550620  6yL5qOKgvBgn4H0XJEDyAV             Silver Bells
# 550621  036JzAN5DCANSZyeW6MjqG        Winter Wonderland
#
#                              album_name                       artists  \
# 0                            UNDEN!ABLE                    [HELLYEAH]
# 1                      Childhood Dreams                     [Yxngxr1]
# 2                   Situationist Comedy              [Dillinger Four]
# 3                        !I'll Be Back!                       [Rilès]
# 4                                !Lost!                       [Rilès]
# ...                                 ...                           ...
# 550617               Damp Chill of Life                        [None]
# 550618               Damp Chill of Life                        [None]
# 550619  Pure Pwnage Season 1 Soundtrack                   [Pronobozo]
# 550620          Another Rosie Christmas  [Sugar Ray, Rosie O'Donnell]
# 550621          Another Rosie Christmas  [Macy Gray, Rosie O'Donnell]
#
#         danceability  energy  key  loudness  mode  speechiness  ...    tempo  \
# 0             0.4150   0.605    7   -11.157     1       0.0575  ...  100.059
# 1             0.7880   0.648    7    -9.135     0       0.3150  ...   79.998
# 2             0.1710   0.957    2    -5.749     1       0.1490  ...  175.317
# 3             0.8230   0.612    1    -7.767     1       0.2480  ...  142.959
# 4             0.7290   0.552    7    -8.562     0       0.0650  ...   86.103
# ...              ...     ...  ...       ...   ...          ...  ...      ...
# 550617        0.2370   0.335    7   -11.895     1       0.0499  ...  140.627
# 550618        0.0966   0.356    7    -8.289     0       0.0418  ...   85.559
# 550619        0.4870   0.698   11   -12.785     0       0.0455  ...  134.967
# 550620        0.7390   0.737    3    -5.372     1       0.0316  ...  120.035
# 550621        0.6760   0.427    7    -8.097     1       0.0313  ...  110.958
#
#         duration_ms                                             lyrics  year  \
# 0             79500  He said he came from Jamaica,\nhe owned a coup...  2016
# 1            114000  Fuck the bitch, now she running with my kids\n...  2019
# 2            197400  You like to stand on the other side\nPoint and...  2002
# 3            178533  It's been a while, shit, I missed the rehab, p...  2018
# 4            186197  I would like to give you all my time\nI would ...  2018
# ...             ...                                                ...   ...
# 550617       477294  Guess there's nothing to do\nAnd nothing to sa...  2019
# 550618       356752  It's quiet here, like I dreamed\nNo response, ...  2019
# 550619       191922  Start the party you see how fun I can dance\n ...  2007
# 550620       159267  City sidewalks, busy sidewalks\nDressed in hol...  2000
# 550621       179573  Sleigh bells ring, are you listening?\nIn the ...  2000
#
#              genre  popularity total_artist_followers  avg_artist_popularity  \
# 0             Rock           0                 769490                   52.0
# 1          Hip-Hop          29                 143628                   45.0
# 2             Rock           0                  36619                   35.0
# 3          Hip-Hop          43                 929303                   63.0
# 4          Hip-Hop           0                 929303                   63.0
# ...            ...         ...                    ...                    ...
# 550617        Rock          30                  45544                   32.0
# 550618        Rock          38                  45544                   32.0
# 550619  Electronic           3                   5479                   25.0
# 550620         Pop          24                1068149                   52.5
# 550621         Pop          25                 770046                   52.0
#
#                                               artist_ids  \
# 0                               [4hxDvVq5t8ebPYPdBl1F9f]
# 1                               [2jwRHcdgkRhelYEMqndDKe]
# 2                               [4YAN46l70QV0PGXlMg0iHi]
# 3                               [6pdcQa7by8IKuoVXvgknlI]
# 4                               [6pdcQa7by8IKuoVXvgknlI]
# ...                                                  ...
# 550617                          [2ZO5sFPyILDQkFdS4HJPFS]
# 550618                          [2ZO5sFPyILDQkFdS4HJPFS]
# 550619                          [4e0ETTbxMHwq7DtH9LSHAJ]
# 550620  [4uN3DsfENc7dp0OLO0FEIb, 4V8U8U6LwsHGyRTLCt9t19]
# 550621  [4ylR3zwA0zaapAu94fktwa, 4V8U8U6LwsHGyRTLCt9t19]
#
#                                              niche_genres
# 0                               ["groove metal", "metal"]
# 1                                         No niche genres
# 2       ["melodic hardcore", "pop punk", "punk", "skat...
# 3                                          ["french rap"]
# 4                                          ["french rap"]
# ...                                                   ...
# 550617                                    ["black metal"]
# 550618                                    ["black metal"]
# 550619                                       ["big beat"]
# 550620                                      ["christmas"]
# 550621                                      ["christmas"]
#
# [550622 rows x 24 columns]

# %%
df_analise = df_songs.explode(["artists", "artist_ids"])
df_analise
# Out:
#                             id                 name  \
# 0       0Prct5TDjAnEgIqbxcldY9                    !
# 1       2ASl4wirkeYm3OWZxXKYuq                   !!
# 2       5tA3ImW310llKo8EMBj2Ga  !!Noble Stabbings!!
# 3       0fROT4kK5oTm8xO8PX6EJF       !I'll Be Back!
# 4       1xBFhv5faebv3mmwxx7DnS               !Lost!
# ...                        ...                  ...
# 550619  0fMJpTECbr7MwQYJjopAWf           Once Again
# 550620  6yL5qOKgvBgn4H0XJEDyAV         Silver Bells
# 550620  6yL5qOKgvBgn4H0XJEDyAV         Silver Bells
# 550621  036JzAN5DCANSZyeW6MjqG    Winter Wonderland
# 550621  036JzAN5DCANSZyeW6MjqG    Winter Wonderland
#
#                              album_name          artists  danceability  \
# 0                            UNDEN!ABLE         HELLYEAH         0.415
# 1                      Childhood Dreams          Yxngxr1         0.788
# 2                   Situationist Comedy   Dillinger Four         0.171
# 3                        !I'll Be Back!            Rilès         0.823
# 4                                !Lost!            Rilès         0.729
# ...                                 ...              ...           ...
# 550619  Pure Pwnage Season 1 Soundtrack        Pronobozo         0.487
# 550620          Another Rosie Christmas        Sugar Ray         0.739
# 550620          Another Rosie Christmas  Rosie O'Donnell         0.739
# 550621          Another Rosie Christmas        Macy Gray         0.676
# 550621          Another Rosie Christmas  Rosie O'Donnell         0.676
#
#         energy  key  loudness  mode  speechiness  ...    tempo  duration_ms  \
# 0        0.605    7   -11.157     1       0.0575  ...  100.059        79500
# 1        0.648    7    -9.135     0       0.3150  ...   79.998       114000
# 2        0.957    2    -5.749     1       0.1490  ...  175.317       197400
# 3        0.612    1    -7.767     1       0.2480  ...  142.959       178533
# 4        0.552    7    -8.562     0       0.0650  ...   86.103       186197
# ...        ...  ...       ...   ...          ...  ...      ...          ...
# 550619   0.698   11   -12.785     0       0.0455  ...  134.967       191922
# 550620   0.737    3    -5.372     1       0.0316  ...  120.035       159267
# 550620   0.737    3    -5.372     1       0.0316  ...  120.035       159267
# 550621   0.427    7    -8.097     1       0.0313  ...  110.958       179573
# 550621   0.427    7    -8.097     1       0.0313  ...  110.958       179573
#
#                                                    lyrics  year       genre  \
# 0       He said he came from Jamaica,\nhe owned a coup...  2016        Rock
# 1       Fuck the bitch, now she running with my kids\n...  2019     Hip-Hop
# 2       You like to stand on the other side\nPoint and...  2002        Rock
# 3       It's been a while, shit, I missed the rehab, p...  2018     Hip-Hop
# 4       I would like to give you all my time\nI would ...  2018     Hip-Hop
# ...                                                   ...   ...         ...
# 550619  Start the party you see how fun I can dance\n ...  2007  Electronic
# 550620  City sidewalks, busy sidewalks\nDressed in hol...  2000         Pop
# 550620  City sidewalks, busy sidewalks\nDressed in hol...  2000         Pop
# 550621  Sleigh bells ring, are you listening?\nIn the ...  2000         Pop
# 550621  Sleigh bells ring, are you listening?\nIn the ...  2000         Pop
#
#         popularity total_artist_followers  avg_artist_popularity  \
# 0                0                 769490                   52.0
# 1               29                 143628                   45.0
# 2                0                  36619                   35.0
# 3               43                 929303                   63.0
# 4                0                 929303                   63.0
# ...            ...                    ...                    ...
# 550619           3                   5479                   25.0
# 550620          24                1068149                   52.5
# 550620          24                1068149                   52.5
# 550621          25                 770046                   52.0
# 550621          25                 770046                   52.0
#
#                     artist_ids  \
# 0       4hxDvVq5t8ebPYPdBl1F9f
# 1       2jwRHcdgkRhelYEMqndDKe
# 2       4YAN46l70QV0PGXlMg0iHi
# 3       6pdcQa7by8IKuoVXvgknlI
# 4       6pdcQa7by8IKuoVXvgknlI
# ...                        ...
# 550619  4e0ETTbxMHwq7DtH9LSHAJ
# 550620  4uN3DsfENc7dp0OLO0FEIb
# 550620  4V8U8U6LwsHGyRTLCt9t19
# 550621  4ylR3zwA0zaapAu94fktwa
# 550621  4V8U8U6LwsHGyRTLCt9t19
#
#                                              niche_genres
# 0                               ["groove metal", "metal"]
# 1                                         No niche genres
# 2       ["melodic hardcore", "pop punk", "punk", "skat...
# 3                                          ["french rap"]
# 4                                          ["french rap"]
# ...                                                   ...
# 550619                                       ["big beat"]
# 550620                                      ["christmas"]
# 550620                                      ["christmas"]
# 550621                                      ["christmas"]
# 550621                                      ["christmas"]
#
# [679269 rows x 24 columns]

# %%
df_artistas_musicas = df_analise.merge(df_artists, left_on="artist_ids", right_on="id", how="left")
#Evitar duplicações de tabelas, poderia ser solucionado no merge antes
df_artistas_musicas = df_artistas_musicas.drop(columns=["artists"]) \
                     .rename(columns={"name": "artist"})
df_artistas_musicas
# Out:
#                           id_x               name_x  \
# 0       0Prct5TDjAnEgIqbxcldY9                    !
# 1       2ASl4wirkeYm3OWZxXKYuq                   !!
# 2       5tA3ImW310llKo8EMBj2Ga  !!Noble Stabbings!!
# 3       0fROT4kK5oTm8xO8PX6EJF       !I'll Be Back!
# 4       1xBFhv5faebv3mmwxx7DnS               !Lost!
# ...                        ...                  ...
# 679264  0fMJpTECbr7MwQYJjopAWf           Once Again
# 679265  6yL5qOKgvBgn4H0XJEDyAV         Silver Bells
# 679266  6yL5qOKgvBgn4H0XJEDyAV         Silver Bells
# 679267  036JzAN5DCANSZyeW6MjqG    Winter Wonderland
# 679268  036JzAN5DCANSZyeW6MjqG    Winter Wonderland
#
#                              album_name  danceability  energy  key  loudness  \
# 0                            UNDEN!ABLE         0.415   0.605    7   -11.157
# 1                      Childhood Dreams         0.788   0.648    7    -9.135
# 2                   Situationist Comedy         0.171   0.957    2    -5.749
# 3                        !I'll Be Back!         0.823   0.612    1    -7.767
# 4                                !Lost!         0.729   0.552    7    -8.562
# ...                                 ...           ...     ...  ...       ...
# 679264  Pure Pwnage Season 1 Soundtrack         0.487   0.698   11   -12.785
# 679265          Another Rosie Christmas         0.739   0.737    3    -5.372
# 679266          Another Rosie Christmas         0.739   0.737    3    -5.372
# 679267          Another Rosie Christmas         0.676   0.427    7    -8.097
# 679268          Another Rosie Christmas         0.676   0.427    7    -8.097
#
#         mode  speechiness  acousticness  ...  total_artist_followers  \
# 0          1       0.0575      0.001160  ...                  769490
# 1          0       0.3150      0.900000  ...                  143628
# 2          1       0.1490      0.000029  ...                   36619
# 3          1       0.2480      0.168000  ...                  929303
# 4          0       0.0650      0.183000  ...                  929303
# ...      ...          ...           ...  ...                     ...
# 679264     0       0.0455      0.000049  ...                    5479
# 679265     1       0.0316      0.001610  ...                 1068149
# 679266     1       0.0316      0.001610  ...                 1068149
# 679267     1       0.0313      0.248000  ...                  770046
# 679268     1       0.0313      0.248000  ...                  770046
#
#         avg_artist_popularity              artist_ids  \
# 0                        52.0  4hxDvVq5t8ebPYPdBl1F9f
# 1                        45.0  2jwRHcdgkRhelYEMqndDKe
# 2                        35.0  4YAN46l70QV0PGXlMg0iHi
# 3                        63.0  6pdcQa7by8IKuoVXvgknlI
# 4                        63.0  6pdcQa7by8IKuoVXvgknlI
# ...                       ...                     ...
# 679264                   25.0  4e0ETTbxMHwq7DtH9LSHAJ
# 679265                   52.5  4uN3DsfENc7dp0OLO0FEIb
# 679266                   52.5  4V8U8U6LwsHGyRTLCt9t19
# 679267                   52.0  4ylR3zwA0zaapAu94fktwa
# 679268                   52.0  4V8U8U6LwsHGyRTLCt9t19
#
#                                              niche_genres  \
# 0                               ["groove metal", "metal"]
# 1                                         No niche genres
# 2       ["melodic hardcore", "pop punk", "punk", "skat...
# 3                                          ["french rap"]
# 4                                          ["french rap"]
# ...                                                   ...
# 679264                                       ["big beat"]
# 679265                                      ["christmas"]
# 679266                                      ["christmas"]
# 679267                                      ["christmas"]
# 679268                                      ["christmas"]
#
#                           id_y           name_y  followers popularity_y  \
# 0       4hxDvVq5t8ebPYPdBl1F9f         HELLYEAH     769490           52
# 1       2jwRHcdgkRhelYEMqndDKe          Yxngxr1     143628           45
# 2       4YAN46l70QV0PGXlMg0iHi   Dillinger Four      36619           35
# 3       6pdcQa7by8IKuoVXvgknlI            Rilès     929303           63
# 4       6pdcQa7by8IKuoVXvgknlI            Rilès     929303           63
# ...                        ...              ...        ...          ...
# 679264  4e0ETTbxMHwq7DtH9LSHAJ        Pronobozo       5479           25
# 679265  4uN3DsfENc7dp0OLO0FEIb        Sugar Ray    1063929           62
# 679266  4V8U8U6LwsHGyRTLCt9t19  Rosie O'Donnell       4220           43
# 679267  4ylR3zwA0zaapAu94fktwa        Macy Gray     765826           61
# 679268  4V8U8U6LwsHGyRTLCt9t19  Rosie O'Donnell       4220           43
#
#                                                    genres  main_genre
# 0                               ['groove metal', 'metal']        Rock
# 1                                                      []     Hip-Hop
# 2       ['punk', 'skate punk', 'melodic hardcore', 'po...        Rock
# 3                                          ['french rap']     Hip-Hop
# 4                                          ['french rap']     Hip-Hop
# ...                                                   ...         ...
# 679264                                       ['big beat']  Electronic
# 679265                                                 []        Folk
# 679266                                      ['christmas']         Pop
# 679267                                                 []     Hip-Hop
# 679268                                      ['christmas']         Pop
#
# [679269 rows x 29 columns]
